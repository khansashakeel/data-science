# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('heart.csv')
data.head(15)
# Out:
#     age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0    52    1   0       125   212    0        1      168      0      1.0
# 1    53    1   0       140   203    1        0      155      1      3.1
# 2    70    1   0       145   174    0        1      125      1      2.6
# 3    61    1   0       148   203    0        1      161      0      0.0
# 4    62    0   0       138   294    1        1      106      0      1.9
# 5    58    0   0       100   248    0        0      122      0      1.0
# 6    58    1   0       114   318    0        2      140      0      4.4
# 7    55    1   0       160   289    0        0      145      1      0.8
# 8    46    1   0       120   249    0        0      144      0      0.8
# 9    54    1   0       122   286    0        0      116      1      3.2
# 10   71    0   0       112   149    0        1      125      0      1.6
# 11   43    0   0       132   341    1        0      136      1      3.0
# ...

# %%
data.shape
# Out:
# (1025, 14)

# %%
data['target'].value_counts()
# Out:
# 1    526
# 0    499
# Name: target, dtype: int64

# %%
plt.pie(data.target.value_counts().values , labels=['detected','not-detected'],autopct='%0.0f%%')
plt.title('disease ratio')
plt.show()

# %%
plt.figure(figsize=(15,5))



##### pie chart for age ####
plt.subplot(1,3,1)
plt.pie(data['age'].value_counts().values , labels=data['age'].value_counts().index)
plt.title('pie chart')


###### bar plot for age ####
plt.subplot(1,3,2)
plt.bar(x=data['age'].value_counts().index,height=data['age'].value_counts().values)
plt.xticks(data['age'].value_counts().index)
plt.title('bar chart')

###### scatter plot for age ####
plt.subplot(1,3,3)
plt.scatter(data['age'].value_counts().index,data['age'].value_counts().values)
plt.title('scatter chart')

plt.show()

# %%
plt.figure(figsize=(15,5))



##### pie chart for ca ####
plt.subplot(1,3,1)
plt.pie(data['ca'].value_counts().values , labels=data['ca'].value_counts().index,autopct='%1.1f%%')
plt.title('pie chart')


###### bar plot for ca ####
plt.subplot(1,3,2)
plt.bar(x=data['ca'].value_counts().index,height=data['ca'].value_counts().values)
plt.xticks(data['ca'].value_counts().index)
plt.title('bar chart')

###### scatter plot for ca ####
plt.subplot(1,3,3)
plt.scatter(data['ca'].value_counts().index,data['ca'].value_counts().values)
plt.plot(data['ca'].value_counts().index,data['ca'].value_counts().values)
plt.title('scatter chart')

plt.show()

# %%
plt.figure(figsize=(15,5))



##### pie chart for cp ####
plt.subplot(1,3,1)
plt.pie(data['cp'].value_counts().values , labels=data['cp'].value_counts().index,autopct='%1.1f%%')
plt.title('pie chart')


###### bar plot for cp ####
plt.subplot(1,3,2)
plt.bar(x=data['cp'].value_counts().index,height=data['cp'].value_counts().values)
plt.xticks(data['cp'].value_counts().index)
plt.title('bar chart')

###### scatter plot for cp ####
plt.subplot(1,3,3)
plt.scatter(data['cp'].value_counts().index,data['cp'].value_counts().values)
plt.title('scatter chart')

plt.show()

# %%
plt.figure(figsize=(15,5))


##### pie chart for fbs ####
plt.subplot(1,3,1)
plt.pie(data['fbs'].value_counts().values , labels=data['fbs'].value_counts().index,autopct='%1.1f%%')
plt.title('pie chart')


###### bar plot for fbs ####
plt.subplot(1,3,2)
plt.bar(x=data['fbs'].value_counts().index,height=data['fbs'].value_counts().values,color=['blue','green','red','pink','yellow'])
plt.xticks(data['fbs'].value_counts().index)
plt.title('bar chart')

plt.show()

# %%
plt.figure(figsize=(15,5))


##### pie chart for thal ####
plt.subplot(1,3,1)
plt.pie(data['thal'].value_counts().values , labels=data['thal'].value_counts().index,autopct='%1.1f%%')
plt.title('pie chart')


###### bar plot for thal ####
plt.subplot(1,3,2)
plt.bar(x=data['thal'].value_counts().index,height=data['thal'].value_counts().values)
plt.xticks(data['thal'].value_counts().index)
plt.title('bar chart')

###### scatter plot for thal ####
plt.subplot(1,3,3)
plt.scatter(data['thal'].value_counts().index,data['thal'].value_counts().values)
plt.plot(data['thal'].value_counts().index,data['thal'].value_counts().values)
plt.title('scatter chart')

plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
arr = data.values

X = arr[:,0:-1]
y = arr[:,-1]

testing_size = 0.2
print(y)
# Out:
# [0. 0. 0. ... 0. 1. 0.]

# %%
X = data.drop('target',axis=1)
y = data['target']
print(y)
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1020    1
# 1021    0
# 1022    0
# 1023    1
# 1024    0
# Name: target, Length: 1025, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=testing_size)
print(y_test)
# Out:
# 948    0
# 682    0
# 829    0
# 24     1
# 283    1
#       ..
# 833    0
# 400    0
# 557    1
# 171    0
# 541    1
# Name: target, Length: 205, dtype: int64

# %%
DT = DecisionTreeClassifier()
DT.fit(X_train, y_train)
y_pred = DT.predict(X_test)
acc = accuracy_score(y_test, y_pred)*100
print(f"Decision Tree accuracy score is: {acc}")
# Out:
# Decision Tree accuracy score is: 100.0

# %%
RT = RandomForestClassifier()
RT.fit(X_train, y_train)
y_pred = RT.predict(X_test)
acc = accuracy_score(y_test, y_pred)*100
print(f"Random Forest accuracy is: {acc}")
# Out:
# Random Forest accuracy is: 100.0

# %%
models = []
models.append(('DT',DecisionTreeClassifier()))
models.append(('RT',RandomForestClassifier()))
models.append(('KNN', KNeighborsClassifier()))
models.append(('LR', LogisticRegression()))
models.append(('GNB', GaussianNB()))
print(models)
# Out:
# [('DT', DecisionTreeClassifier()), ('RT', RandomForestClassifier()), ('KNN', KNeighborsClassifier()), ('LR', LogisticRegression()), ('GNB', GaussianNB())]

# %%
names = []
results = []

for name, model in models:
    obj = model
    names.append(name)
    obj.fit(X_train, y_train)
    y_pred = obj.predict(X_test)
    results.append(accuracy_score(y_test, y_pred)*100)
    
print(results)
# Out:
# [100.0, 100.0, 66.34146341463415, 79.02439024390245, 78.04878048780488]
# C:\Users\khans\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
plt.figure(figsize=(15,5))

plt.subplot(1,2,1)
plt.bar(names, results, color=['blue','yellow','grey','pink','orange'])

plt.subplot(1,2,2)
plt.scatter(names, results)
# plt.plot(names, results)
plt.show()
